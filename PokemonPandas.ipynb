# %% [markdown]
# # Loading Data

# %%
import pandas as pd

#DataFrame usando uma função do pandas para ler csv
df = pd.read_csv('pokemon_data.csv')

# %% [markdown]
# # Reading Data

# %%
##Read headers
##print(df.columns)

##Ler cada Coluna
##print(df[['Name','Type 1','HP']])

##Ler cada linha
#print(df.iloc[0:4])

#for index, row in df.iterrows():
#    print(index,row['Name'])

df.loc[df['Type 1'] == 'Ghost']

##Especificar a localização (L,C)
#print(df.iloc[2,1])

# %% [markdown]
# # Sorting describing Data

# %%
#df.describe()

df.sort_values(['Type 1','HP'], ascending=False)
# Out:
#        #       Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 351  321    Wailord  Water     NaN  170      90       45       90       45
# 655  594  Alomomola  Water     NaN  165      75       80       40       45
# 142  131     Lapras  Water     Ice  130      85       80       85       95
# 145  134   Vaporeon  Water     NaN  130      65       60      110       95
# 350  320    Wailmer  Water     NaN  130      70       35       70       35
# ..   ...        ...    ...     ...  ...     ...      ...      ...      ...
# 314  290    Nincada    Bug  Ground   31      45       90       30       30
# 462  415     Combee    Bug  Flying   30      30       42       30       42
# 603  543   Venipede    Bug  Poison   30      45       59       30       39
# 230  213    Shuckle    Bug    Rock   20      10      230       10      230
# 316  292   Shedinja    Bug   Ghost    1      90       45       30       30
#
#      Speed  Generation  Legendary
# ...

# %% [markdown]
# # Making Changes to the Data

# %%
#df['TotalStatus'] = df ['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']

#df.drop(columns=['Total'])

df['TotalStatus'] = df.iloc[:, 4:9].sum(axis=1) #better huh?

cols = list(df.columns)
df = df[cols[0:4] + [cols[-1]]+cols[4:12]]

df.head(5)
# Out:
#    #                   Name Type 1  Type 2  TotalStatus  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison          273  45      49       49
# 1  2                Ivysaur  Grass  Poison          345  60      62       63
# 2  3               Venusaur  Grass  Poison          445  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison          545  80     100      123
# 4  4             Charmander   Fire     NaN          244  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# # Saving/exporting Data

# %%
#df.to_csv('modified.csv', index=False)

#df.to_excel('modified.xlsx', index=False)

#df.to_csv('modified.txt', index=False, sep='\t')

# %% [markdown]
# # Filtering data

# %%
#new_df = df.loc[(df['Type 1']=='Grass') & (df['Type 2'] == 'Poison') & (df['HP']>70)]
import re

df.loc[df['Name'].str.contains('^pi[a-z]*', flags=re.I, regex=True)]

#new_df.to_csv('filtered.csv')

#new_df.reset_index(drop=True, inplace=True)

#new_df
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 20    16               Pidgey    Normal    Flying   40      45       40
# 21    17            Pidgeotto    Normal    Flying   63      60       55
# 22    18              Pidgeot    Normal    Flying   83      80       75
# 23    18  PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 30    25              Pikachu  Electric       NaN   35      55       40
# 136  127               Pinsir       Bug       NaN   65     125      100
# 137  127    PinsirMega Pinsir       Bug    Flying   65     155      120
# 186  172                Pichu  Electric       NaN   20      40       15
# 219  204               Pineco       Bug       NaN   50      65       90
# 239  221            Piloswine       Ice    Ground  100     100       80
# 438  393               Piplup     Water       NaN   53      51       53
# 558  499              Pignite      Fire  Fighting   90      93       55
# ...

# %% [markdown]
# # Conditional Changes

# %%
#df.loc[df['Type 1'] == 'Flamer', 'Type 1'] = 'Fire'
#df

df = pd.read_csv('modified.csv')

#df.loc[df['Total'] > 500, ['Generation','Legendary']] = ['Test 1', 'Test 2']

# %% [markdown]
# # Aggregate Statistics(Groupby)

# %%
df = pd.read_csv('modified.csv')

df['count'] = 1

df.groupby(['Type 1', 'Type 2']).count()['count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64

# %% [markdown]
# # Working with large amounts of data

# %%
new_df = pd.DataFrame(columns=df.columns)

for df in pd.read_csv('modified.csv', chunksize=5):
    results = df.groupby(['Type 1']).count()
    
    new_df = pd.concat([new_df, results])
